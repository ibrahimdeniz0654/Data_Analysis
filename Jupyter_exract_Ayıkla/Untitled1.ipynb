# %% [markdown]
# # C9262-ibrahim D. is inviting you to a scheduled Zoom meeting.
#
# Topic: Cuma Günü Takım Çalışması
# Time: Jul 2, 2021 08:00 PM Amsterdam, Berlin, Rome, Stockholm, Vienna
#
# Join Zoom Meeting
# https://us04web.zoom.us/j/74147242623?pwd=MUQ2ZHJTcmxPTDhyZ1pZUGtiUnRxZz09
#
# Meeting ID: 741 4724 2623
# Passcode: 1aeD6s

# %% [markdown]
# #

# %% [markdown]
# # ![image.png](attachment:image.png)
