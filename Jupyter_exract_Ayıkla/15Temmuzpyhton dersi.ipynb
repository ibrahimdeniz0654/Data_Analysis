# %%
num =int(input("Enter a number: "))
if 8

# %% [markdown]
# ![image.png](attachment:image.png)#

# %% [markdown]
# # #Öncelikle kullanıcıdan bir sayı isteniyor
# sayi = input('Bir Sayı Giriniz : ')
#
# #Sayının pozitif mi negatif mi sıfır mı olduğunu if ile kontrol ediyoruz.
#
# if(int(sayi)>0):
#      print(sayi +" Sayısı Pozitif Sayıdır.")
#
# if(int(sayi)<0):
#      print(sayi +" Sayısı Negatif Sayıdır.")
#
# if(int(sayi)==0):
#      print(sayi +" Sayısı Sıfırdır.")

# %%
sayi = input("Bir Sayı Giriniz : ")
# Out:
# Bir Sayı Giriniz : 10

# %%
if(int(sayi)>0): print(sayi+"Sayısı Pozitif Sayıdır.")
# Out:
# 10Sayısı Pozitif Sayıdır.

# %%
num1 = float(input("Enter the first number please : "))
num2 = float(input("Enter the second number please :"))

if num1 > num2 : 
        larger = num1
else : 
        larger = num2

    print("The larger number is : ", larger)
# Out:
#   File "<tokenize>", line 9
#     print("The larger number is : ", larger)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
sayi = input('Bir Sayı Giriniz : ')

#Sayının pozitif mi negatif mi sıfır mı olduğunu if ile kontrol ediyoruz.

if(int(sayi)>0): print(sayi +" Sayısı Pozitif Sayıdır.")

if(int(sayi)<0): print(sayi +" Sayısı Negatif Sayıdır.")

if(int(sayi)==0): print(sayi +" Sayısı Sıfırdır.")

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
num1 = float(input("Enter first number :"))
num2 = float(input("Enter secnod number :"))
num3 = float(input("Enter third number :"))

if ( num1 > num2) and (num1 > num3) :
    largest = num1
elif (num2 > num1) and (num2 > num3) :
    lagerst = num2
else :
    largerst = num3
print("Girilen 3 sayıdan en büyüğü : ", largerst)
# Out:
# Enter first number :10
# Enter secnod number :20
# Enter third number :30
# Girilen 3 sayıdan en büyüğü :  30.0

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)#

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
not = float(input("Sınavdan aldığınız Puaanı Giriniz: "))
if not > 94 :
    print("Sınav Notunuz A+")
elif not > 89
    print ("Sınv Notunuz A")
elif not > 84 :
    print("Sına Notunuz B+")
elif not > 79 :
    print("Sınav Notunuz B")
# Out:
#   File "<ipython-input-13-2b9fe2dc17a1>", line 1
#     not = float(input("Sınavdan aldığınız Puaanı Giriniz: "))
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
result= light_pipeline.annotate ("cari açık Türkiye için büyük risk")
result["class"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dd8a4dfd82a2> in <module>
# ----> 1 result= light_pipeline.annotate ("cari açık Türkiye için büyük risk")
#       2 result["class"]
#
# NameError: name 'light_pipeline' is not defined

# %%
# yukarıda yapay zeka algoritması ile bir açılım kodu...

# %%
items = (10, 20)

# %%
x, y = items

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
left = {"q", "w", "e", "r", "t", "a", "s", "d", "f", "g", "z", "x", "c", "v", "b"}
right = {"y", "u", "i", "o", "p", "h", "j", "k", "l", "n", "m"}
word = "test"

# %%
set_word = set(word)
set_word
# Out:
# {'e', 's', 't'}

# %%
left_bool = bool(set_word - left)
left_bool
# Out:
# False

# %% [markdown]
# # ![image.png](attachment:image.png)
