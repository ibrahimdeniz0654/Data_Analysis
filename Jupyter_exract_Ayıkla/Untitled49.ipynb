# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_html('https://www.bbc.com/news/world-51235105')
df
# Out:
# [              Country  Deaths  Death rate*  Total Cases  \
#  0                  US  986953        300.7     80459923
#  1              Brazil  662964        314.1     30355919
#  2               India  522223         38.2     43060086
#  3              Russia  367521        254.6     17880154
#  4              Mexico  324134        254.1      5733925
#  ..                ...     ...          ...          ...
#  220           Vatican       0          0.0           29
#  221  Marshall Islands       0          0.0           17
#  222        Antarctica       0          NaN           11
#  223      Saint Helena       0          0.0            4
#  224        Micronesia       0          0.0            3
#
#       New Cases  0  10  100  1k  10k  **  Unnamed: 5
#  0                                   NaN         NaN
#  1                                   NaN         NaN
#  2                                   NaN         NaN
#  3                                   NaN         NaN
# ...

# %%
df1 = df[0]
df1
# Out:
#               Country  Deaths  Death rate*  Total Cases  \
# 0                  US  986953        300.7     80459923
# 1              Brazil  662964        314.1     30355919
# 2               India  522223         38.2     43060086
# 3              Russia  367521        254.6     17880154
# 4              Mexico  324134        254.1      5733925
# ..                ...     ...          ...          ...
# 220           Vatican       0          0.0           29
# 221  Marshall Islands       0          0.0           17
# 222        Antarctica       0          NaN           11
# 223      Saint Helena       0          0.0            4
# 224        Micronesia       0          0.0            3
#
#      New Cases  0  10  100  1k  10k  **  Unnamed: 5
# 0                                   NaN         NaN
# 1                                   NaN         NaN
# 2                                   NaN         NaN
# 3                                   NaN         NaN
# ...

# %%
df1.to_csv("C://Users//PC-AYSBERG//Desktop//htmldatanput//deneme.csv")

# %%
df2 = pd.read_csv("C://Users//PC-AYSBERG//Desktop//htmldatanput//deneme.csv")
df2
# Out:
#      Unnamed: 0           Country  Deaths  Death rate*  Total Cases  \
# 0             0                US  986953        300.7     80459923
# 1             1            Brazil  662964        314.1     30355919
# 2             2             India  522223         38.2     43060086
# 3             3            Russia  367521        254.6     17880154
# 4             4            Mexico  324134        254.1      5733925
# ..          ...               ...     ...          ...          ...
# 220         220           Vatican       0          0.0           29
# 221         221  Marshall Islands       0          0.0           17
# 222         222        Antarctica       0          NaN           11
# 223         223      Saint Helena       0          0.0            4
# 224         224        Micronesia       0          0.0            3
#
#      New Cases  0  10  100  1k  10k  **  Unnamed: 5
# 0                                   NaN         NaN
# ...
