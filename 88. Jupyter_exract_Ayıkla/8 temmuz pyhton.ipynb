# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2020,
  "year": 1964
}

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
first_dict = {1: "one", "two" : 2, False [1, 2, 3]}
firs_dict
# Out:
#   File "<ipython-input-10-48ac7f44a6ba>", line 1
#     first_dict = {1: "one", "two" : 2, False [1, 2, 3]}
#                                                       ^
# SyntaxError: invalid syntax

# %%
first_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2624ddfc6f50> in <module>
# ----> 1 first_dict
#
# NameError: name 'first_dict' is not defined

# %%
fifth_dict = {erkekler :{"ahmet" : 35, "mehmet" : 44, "cevat" : 17},\
             "bayanlar" : {"selvi" : 22, "bahar" : 55, "ayşe" : 3}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fc1b8541a36d> in <module>
# ----> 1 fifth_dict = {erkekler :{"ahmet" : 35, "mehmet" : 44, "cevat" : 17},\
#       2              "bayanlar" : {"selvi" : 22, "bahar" : 55, "ayşe" : 3}}
#
# NameError: name 'erkekler' is not defined

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
family = {"name1":"sevil",
            "name2":"Kerim"
          }
family
# Out:
# {'name1': 'sevil', 'name2': 'Kerim'}
